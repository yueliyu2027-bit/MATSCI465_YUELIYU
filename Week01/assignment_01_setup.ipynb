# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/NU-MSE-LECTURES/465_Computational_Microscopy_2026/blob/dev/Week_01/assignments/assignment_01_setup.ipynb)
#
# # Assignment 1: Environment Setup and Python Basics
# **Due Date:** January 12, 2026
#
# ## Instructions
# 1.  Complete the tasks in the cells below.
# 2.  Ensure all code runs without errors.
# 3.  Submit your completed notebook via Canvas (or GitHub if instructed).

# %%
# Colab setup
try:
    import google.colab
    IN_COLAB = True
    print("Running in Google Colab. Installing requirements...")
    # !pip install hyperspy ase py4DSTEM
    # !git clone https://github.com/NU-MSE-LECTURES/465_Computational_Microscopy_2026.git
    print("Setup complete.")
except ImportError:
    IN_COLAB = False
    print("Not running in Google Colab.")
# Out:
# Not running in Google Colab.

# %% [markdown]
# ## Task 1: Environment Verification
#
# Write a Python script to:
# 1.  Import `sys`, `numpy`, and `matplotlib`.
# 2.  Print the Python version.
# 3.  Print the versions of `numpy` and `matplotlib`.

# %%
# Task 1: Environment info (local Jupyter)
import sys
import platform

import numpy as np
import scipy
import matplotlib
import hyperspy
import py4DSTEM

print("Python version:", sys.version)
print("OS / Platform:", platform.platform())

print("NumPy:", np.__version__)
print("SciPy:", scipy.__version__)
print("Matplotlib:", matplotlib.__version__)
print("HyperSpy:", hyperspy.__version__)
print("py4DSTEM:", py4DSTEM.__version__)

print("\nAll required libraries imported successfully.")
# Out:
# Python version: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# OS / Platform: Windows-10-10.0.26200-SP0
# NumPy: 1.26.4
# SciPy: 1.15.2
# Matplotlib: 3.10.8
# HyperSpy: 2.3.0
# py4DSTEM: 0.14.18
#
# All required libraries imported successfully.

# %% [markdown]
# ## Task 2: Automate Project Structure
#
# Write a Python script using `os` or `pathlib` to programmatically create the following directory structure inside a folder named `assignment_01_output`:
# ```
# assignment_01_output/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── figures/
# └── src/
# ```

# %%
# Your code here
# Task 2: Automate project structure
from pathlib import Path

# Define base directory
base_dir = Path("assignment_01_output")

# Define subdirectories
dirs = [
    base_dir / "data" / "raw",
    base_dir / "data" / "processed",
    base_dir / "figures"
]

# Create directories
for d in dirs:
    d.mkdir(parents=True, exist_ok=True)

print("Project directory structure created successfully.")
# Out:
# Project directory structure created successfully.

# %% [markdown]
# ## Task 3: Ensure Reproducibility
#
# Demonstrate reproducibility by:
# 1.  Setting a random seed using `numpy.random.seed()`.
# 2.  Generating an array of 5 random numbers.
# 3.  Printing the array.
# 4.  Run the cell multiple times to verify that the numbers remain the same.

# %%
# Task: Demonstrate reproducibility
import numpy as np

# Set random seed
np.random.seed(42)

# Generate 5 random numbers
random_numbers = np.random.rand(5)

# Print the array
print(random_numbers)
# Out:
# [0.37454012 0.95071431 0.73199394 0.59865848 0.15601864]

# %%
from pathlib import Path

raw_dir = Path("assignment_01_output/data/raw")
list(raw_dir.iterdir())
# Out:
# [WindowsPath('assignment_01_output/data/raw/example_EM_Image.tif')]

# %%
import matplotlib.pyplot as plt
import numpy as np

img = plt.imread(raw_dir / "example_EM_Image.tif")
img.shape
# Out:
# (503, 503, 3)

# %%
plt.imshow(img, cmap="gray")
plt.axis("off")
# Out:
# (-0.5, 502.5, 502.5, -0.5)

# %%
img.mean(), img.std()
# Out:
# (59.01474651099368, 67.21953500177058)

# %%
plt.hist(img.flatten(), bins=50)
plt.xlabel("Intensity")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# The original image exhibits the characteristics of a two-dimensional periodic lattice, while the background presents purple granular noise, which is not simply white noise; On the left side of the intensity histogram, it is higher, indicating that most of the space is not atomic positions. The middle area corresponds to diffusion signals around atoms, while the right side has fewer pixels but higher intensity, indicating the position of atoms. This is a strong scattering or high electron density area.
